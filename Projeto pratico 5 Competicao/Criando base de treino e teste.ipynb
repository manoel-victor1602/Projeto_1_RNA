# %%
import pandas as pd
import numpy as np

# %%
df_data = pd.read_csv('dataR2.csv')

# %%
df_test = pd.read_csv('test.csv')

# %%
df_data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
df_data.BMI = df_data.BMI.apply(round, args=[4])
df_data.HOMA = df_data.HOMA.apply(round, args=[4])
df_data.Adiponectin = df_data.Adiponectin.apply(round, args=[4])
df_data.Resistin = df_data.Resistin.apply(round, args=[4])

# %%
df_data['Soma'] = [np.sum(d) for d in df_data.drop('Classification', axis=1).values]

# %%
df_test['Soma'] = [np.sum(t) for t in df_test.drop('id', axis=1).values]

# %%
test_ids = [59, 11, 46, 93, 63, 73, 86, 78, 77, 68, 57, 17, 53, 8, 104, 89, 18, 31, 30, 9, 54, 6, 59, 115, 96]

# %%
df_data = df_data.iloc[test_ids, :].sort_values(by='Age')

# %%
df_data = df_data.reset_index()

# %%
df_test = df_test.sort_values(by='Age')

# %%
df_test = df_test.reset_index()
df_test
# Out:
#     index   id  Age      BMI  Glucose  Insulin     HOMA   Leptin  Adiponectin  \
# 0       1   78   29  23.0100       82    5.663   1.1454  35.5900      26.7200
# 1       9   48   43  31.2500      103    4.328   1.0996  25.7816      12.7190
# 2       3  113   44  27.8876       99    9.208   2.2486  12.6757       5.4782
# 3      21   59   45  20.8300       74    4.560   0.8324   7.7529       8.2374
# 4      16   53   46  20.8300       88    3.420   0.7424  12.8700      18.5500
# 5       8   31   48  31.2500      199   12.162   5.9699  18.1314       4.1041
# 6       6   89   49  20.9566       94   12.305   2.8531  11.2406       8.4122
# 7      13   11   49  32.4619      134   24.887   8.2260  42.3914      10.7939
# 8      20   14   51  22.8928      103    2.740   0.6961   8.0163       9.3498
# 9       5   84   53  36.7902      101   10.175   2.5349  27.1841      20.0300
# 10     17   63   57  34.8381       95   12.548   2.9404  33.1612       2.3650
# ...

# %%
df_data['id'] = df_test.id

# %%
df_data = df_data.iloc[:-1, :]

# %%
df_data
# Out:
#     index  Age        BMI  Glucose  Insulin       HOMA   Leptin  Adiponectin  \
# 0      11   29  23.010000       82    5.663   1.145436  35.5900    26.720000
# 1      77   43  31.250000      103    4.328   1.099601  25.7816    12.718960
# 2      96   44  27.887617       99    9.208   2.248594  12.6757     5.478170
# 3      53   45  20.829995       74    4.560   0.832352   7.7529     8.237405
# 4      68   46  20.830000       88    3.420   0.742368  12.8700    18.550000
# 5      86   48  28.125000       90    2.540   0.563880  15.5325    10.222310
# 6      54   49  20.956608       94   12.305   2.853119  11.2406     8.412175
# 7      93   49  32.461911      134   24.887   8.225983  42.3914    10.793940
# 8      63   51  22.892820      103    2.740   0.696143   8.0163     9.349775
# 9      31   53  36.790166      101   10.175   2.534932  27.1841    20.030000
# 10    104   57  34.838148       95   12.548   2.940415  33.1612     2.364950
# ...

# %%
df_data.to_csv('test_data.csv', index=False)

# %%
train_ids = [i for i in range(116) if i not in test_ids]

# %%
df_train = df_data.iloc[train_ids, :-1]

# %%
df_test
# Out:
#      Age      BMI  Glucose  Insulin     HOMA   Leptin  Adiponectin  Resistin  \
# 59    62  22.6562       92    3.482   0.7902   9.8648      11.2362   10.6955
# 11    29  23.0100       82    5.663   1.1454  35.5900      26.7200    4.5800
# 96    44  27.8876       99    9.208   2.2486  12.6757       5.4782   23.0331
# 9     75  23.0000       83    4.952   1.0138  17.1270      11.5790    7.0913
# 31    53  36.7902      101   10.175   2.5349  27.1841      20.0300   10.2631
# 54    49  20.9566       94   12.305   2.8531  11.2406       8.4122   23.1177
# 57    68  21.0828      102    6.200   1.5599   9.6994       8.5747   13.7424
# 88    48  31.2500      199   12.162   5.9699  18.1314       4.1041   53.6308
# 77    43  31.2500      103    4.328   1.0996  25.7816      12.7190   38.6531
# 115   86  27.1800      138   19.910   6.7774  90.2800      14.1100    4.3500
# 78    86  26.6667      201   41.611  20.6307  47.6470       5.3571   24.3701
# ...

# %%
df_train.to_csv('train_data.csv', index=False)
