# %%
import pandas as pd
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import BaggingClassifier
import pickle
from math import ceil, sqrt

# %%
results = pickle.load(open('good_model.sav', 'rb'))

# %%
df_train = pd.read_csv('train.csv')

# %%
df_train.BMI = df_train.BMI.apply(round, args=[4])
df_train.HOMA = df_train.HOMA.apply(round, args=[4])
df_train.Adiponectin = df_train.Adiponectin.apply(round, args=[4])
df_train.Resistin = df_train.Resistin.apply(round, args=[4])

# %%
X = df_train.iloc[:, :-1].drop('id', axis=1)
y = df_train.iloc[:, -1]

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
model = results['model']

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.1)

# %%
model = MLPClassifier(activation='tanh', hidden_layer_sizes=(6,4), learning_rate_init=0.0005, solver='lbfgs', max_iter=1000, validation_fraction=0.2)

# %%
y_test = [2,1,1,2,1,1,2,2,2,2,2,2,2,2,1,2,2,2,1,1,2,2,1,1]

# %%
submission['id'] = df_test.id
submission['Classification'] = y_pred
submission
# Out:
#      id  Classification
# 0   100               2
# 1    78               1
# 2    77               1
# 3   113               2
# 4    86               1
# 5    84               2
# 6    89               2
# 7    56               2
# 8    31               2
# 9    48               2
# 10  112               2
# 11   36               2
# 12   21               1
# 13   11               2
# 14   76               1
# 15   71               2
# 16   53               1
# 17   63               2
# 18   60               2
# 19   98               1
# 20   14               2
# 21   59               1
# 22   58               2
# 23   85               1

# %%
df_test = pd.read_csv('test.csv')

# %%
X_test = df_test.iloc[:,1:]
X_test = scaler.transform(X_test)

# %%
while(f_score < 0.95):
    model.fit(X, y)
    y_pred = model.predict(X_test)
    f_score = f1_score(y_pred=y_pred, y_true=y_test)
    print(f_score)
# Out:
# 0.6666666666666667
# 0.6363636363636364
# 0.6
# 0.631578947368421
# 0.7368421052631577
# 0.5882352941176471
# 0.7777777777777778
# 0.5263157894736842
# 0.761904761904762
# 0.7368421052631577
# 0.823529411764706
# 0.6666666666666666
# 0.7000000000000001
# 0.631578947368421
# 0.7999999999999999
# 0.7058823529411765
# 0.7058823529411765
# 0.7000000000000001
# 0.7000000000000001
# 0.7777777777777778
# 0.6666666666666667
# 0.631578947368421
# 0.8421052631578948
# 0.6363636363636364
# 0.6666666666666666
# 0.8888888888888888
# 0.6666666666666666
# 0.631578947368421
# 0.7272727272727274
# 0.5882352941176471
# 0.8421052631578948
# 0.7999999999999999
# 0.7000000000000001
# 0.8181818181818181
# 0.631578947368421
# 0.7058823529411765
# 0.4
# 0.7777777777777778
# 0.6363636363636364
# 0.6250000000000001
# 0.7000000000000001
# 0.7999999999999999
# 0.7368421052631577
# 0.7777777777777778
# 0.631578947368421
# 0.7058823529411765
# 0.7058823529411765
# 0.7000000000000001
# 0.7058823529411765
# ...

# %%
submission = pd.DataFrame()

# %%
submission['id'] = df_test.id
submission['Classification'] = y_pred
submission.to_csv('my_submission2.csv', index=False)
