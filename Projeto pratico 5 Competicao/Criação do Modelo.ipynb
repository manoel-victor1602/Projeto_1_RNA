# %%
# %pylab inline
import pandas as pd
import numpy as np
import pickle

from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score

from math import ceil, sqrt

from collections import defaultdict
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\Users\Inventario-LSE\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['ceil', 'sqrt', 'clf', 'cm']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
def piramid(alpha=2, n_in=7, n_out=1):
    neurons = ceil(alpha * sqrt(n_in * n_out))
    ret = [(neurons,)]
    ret += [(neurons-n, n) for n in range(1, neurons)]
    return ret

# %%
df_train = pd.read_csv('train_data.csv')
df_test = pd.read_csv('test_data.csv')

# %%
X_train = df_train.iloc[:, :-1]
y_train = df_train.iloc[:, -1]
X_test = df_test.iloc[:, :-1]
y_test = df_test.iloc[:, -1]

# %%
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
params = {
    'activation': ['logistic', 'relu', 'tanh'], 
    'max_iter': [600, 800, 1000],
    'learning_rate_init': [0.001, 0.003, 0.01, 0.0005],
    'hidden_layer_sizes': list(piramid(alpha=0.5, n_in=9) + piramid(alpha=2, n_in=9) + piramid(alpha=3, n_in=9))
}

# %%
models = []
for a in params['activation']:
    for m in params['max_iter']:
        for l in params['learning_rate_init']:
            for h in params['hidden_layer_sizes']:
                models.append(['lbfgs', a, m, l, h])
models
# Out:
# [['lbfgs', 'logistic', 600, 0.001, (2,)],
#  ['lbfgs', 'logistic', 600, 0.001, (1, 1)],
#  ['lbfgs', 'logistic', 600, 0.001, (6,)],
#  ['lbfgs', 'logistic', 600, 0.001, (5, 1)],
#  ['lbfgs', 'logistic', 600, 0.001, (4, 2)],
#  ['lbfgs', 'logistic', 600, 0.001, (3, 3)],
#  ['lbfgs', 'logistic', 600, 0.001, (2, 4)],
#  ['lbfgs', 'logistic', 600, 0.001, (1, 5)],
#  ['lbfgs', 'logistic', 600, 0.001, (9,)],
#  ['lbfgs', 'logistic', 600, 0.001, (8, 1)],
#  ['lbfgs', 'logistic', 600, 0.001, (7, 2)],
#  ['lbfgs', 'logistic', 600, 0.001, (6, 3)],
#  ['lbfgs', 'logistic', 600, 0.001, (5, 4)],
#  ['lbfgs', 'logistic', 600, 0.001, (4, 5)],
#  ['lbfgs', 'logistic', 600, 0.001, (3, 6)],
#  ['lbfgs', 'logistic', 600, 0.001, (2, 7)],
#  ['lbfgs', 'logistic', 600, 0.001, (1, 8)],
#  ['lbfgs', 'logistic', 600, 0.003, (2,)],
#  ['lbfgs', 'logistic', 600, 0.003, (1, 1)],
#  ['lbfgs', 'logistic', 600, 0.003, (6,)],
#  ['lbfgs', 'logistic', 600, 0.003, (5, 1)],
#  ['lbfgs', 'logistic', 600, 0.003, (4, 2)],
#  ['lbfgs', 'logistic', 600, 0.003, (3, 3)],
#  ['lbfgs', 'logistic', 600, 0.003, (2, 4)],
#  ['lbfgs', 'logistic', 600, 0.003, (1, 5)],
#  ['lbfgs', 'logistic', 600, 0.003, (9,)],
#  ['lbfgs', 'logistic', 600, 0.003, (8, 1)],
#  ['lbfgs', 'logistic', 600, 0.003, (7, 2)],
#  ['lbfgs', 'logistic', 600, 0.003, (6, 3)],
#  ['lbfgs', 'logistic', 600, 0.003, (5, 4)],
#  ['lbfgs', 'logistic', 600, 0.003, (4, 5)],
#  ['lbfgs', 'logistic', 600, 0.003, (3, 6)],
#  ['lbfgs', 'logistic', 600, 0.003, (2, 7)],
#  ['lbfgs', 'logistic', 600, 0.003, (1, 8)],
#  ['lbfgs', 'logistic', 600, 0.01, (2,)],
#  ['lbfgs', 'logistic', 600, 0.01, (1, 1)],
#  ['lbfgs', 'logistic', 600, 0.01, (6,)],
#  ['lbfgs', 'logistic', 600, 0.01, (5, 1)],
#  ['lbfgs', 'logistic', 600, 0.01, (4, 2)],
#  ['lbfgs', 'logistic', 600, 0.01, (3, 3)],
#  ['lbfgs', 'logistic', 600, 0.01, (2, 4)],
#  ['lbfgs', 'logistic', 600, 0.01, (1, 5)],
#  ['lbfgs', 'logistic', 600, 0.01, (9,)],
#  ['lbfgs', 'logistic', 600, 0.01, (8, 1)],
#  ['lbfgs', 'logistic', 600, 0.01, (7, 2)],
#  ['lbfgs', 'logistic', 600, 0.01, (6, 3)],
#  ['lbfgs', 'logistic', 600, 0.01, (5, 4)],
#  ['lbfgs', 'logistic', 600, 0.01, (4, 5)],
#  ['lbfgs', 'logistic', 600, 0.01, (3, 6)],
#  ['lbfgs', 'logistic', 600, 0.01, (2, 7)],
#  ['lbfgs', 'logistic', 600, 0.01, (1, 8)],
#  ['lbfgs', 'logistic', 600, 0.0005, (2,)],
#  ['lbfgs', 'logistic', 600, 0.0005, (1, 1)],
#  ['lbfgs', 'logistic', 600, 0.0005, (6,)],
#  ['lbfgs', 'logistic', 600, 0.0005, (5, 1)],
#  ['lbfgs', 'logistic', 600, 0.0005, (4, 2)],
#  ['lbfgs', 'logistic', 600, 0.0005, (3, 3)],
#  ['lbfgs', 'logistic', 600, 0.0005, (2, 4)],
#  ['lbfgs', 'logistic', 600, 0.0005, (1, 5)],
#  ['lbfgs', 'logistic', 600, 0.0005, (9,)],
#  ['lbfgs', 'logistic', 600, 0.0005, (8, 1)],
#  ['lbfgs', 'logistic', 600, 0.0005, (7, 2)],
#  ['lbfgs', 'logistic', 600, 0.0005, (6, 3)],
#  ['lbfgs', 'logistic', 600, 0.0005, (5, 4)],
#  ['lbfgs', 'logistic', 600, 0.0005, (4, 5)],
#  ['lbfgs', 'logistic', 600, 0.0005, (3, 6)],
#  ['lbfgs', 'logistic', 600, 0.0005, (2, 7)],
#  ['lbfgs', 'logistic', 600, 0.0005, (1, 8)],
#  ['lbfgs', 'logistic', 800, 0.001, (2,)],
#  ['lbfgs', 'logistic', 800, 0.001, (1, 1)],
#  ['lbfgs', 'logistic', 800, 0.001, (6,)],
#  ['lbfgs', 'logistic', 800, 0.001, (5, 1)],
#  ['lbfgs', 'logistic', 800, 0.001, (4, 2)],
#  ['lbfgs', 'logistic', 800, 0.001, (3, 3)],
#  ['lbfgs', 'logistic', 800, 0.001, (2, 4)],
#  ['lbfgs', 'logistic', 800, 0.001, (1, 5)],
#  ['lbfgs', 'logistic', 800, 0.001, (9,)],
#  ['lbfgs', 'logistic', 800, 0.001, (8, 1)],
#  ['lbfgs', 'logistic', 800, 0.001, (7, 2)],
#  ['lbfgs', 'logistic', 800, 0.001, (6, 3)],
#  ['lbfgs', 'logistic', 800, 0.001, (5, 4)],
#  ['lbfgs', 'logistic', 800, 0.001, (4, 5)],
#  ['lbfgs', 'logistic', 800, 0.001, (3, 6)],
#  ['lbfgs', 'logistic', 800, 0.001, (2, 7)],
#  ['lbfgs', 'logistic', 800, 0.001, (1, 8)],
#  ['lbfgs', 'logistic', 800, 0.003, (2,)],
#  ['lbfgs', 'logistic', 800, 0.003, (1, 1)],
#  ['lbfgs', 'logistic', 800, 0.003, (6,)],
#  ['lbfgs', 'logistic', 800, 0.003, (5, 1)],
#  ['lbfgs', 'logistic', 800, 0.003, (4, 2)],
#  ['lbfgs', 'logistic', 800, 0.003, (3, 3)],
#  ['lbfgs', 'logistic', 800, 0.003, (2, 4)],
#  ['lbfgs', 'logistic', 800, 0.003, (1, 5)],
#  ['lbfgs', 'logistic', 800, 0.003, (9,)],
#  ['lbfgs', 'logistic', 800, 0.003, (8, 1)],
#  ['lbfgs', 'logistic', 800, 0.003, (7, 2)],
#  ['lbfgs', 'logistic', 800, 0.003, (6, 3)],
#  ['lbfgs', 'logistic', 800, 0.003, (5, 4)],
#  ['lbfgs', 'logistic', 800, 0.003, (4, 5)],
#  ['lbfgs', 'logistic', 800, 0.003, (3, 6)],
#  ['lbfgs', 'logistic', 800, 0.003, (2, 7)],
#  ['lbfgs', 'logistic', 800, 0.003, (1, 8)],
#  ['lbfgs', 'logistic', 800, 0.01, (2,)],
#  ['lbfgs', 'logistic', 800, 0.01, (1, 1)],
#  ['lbfgs', 'logistic', 800, 0.01, (6,)],
#  ['lbfgs', 'logistic', 800, 0.01, (5, 1)],
#  ['lbfgs', 'logistic', 800, 0.01, (4, 2)],
#  ['lbfgs', 'logistic', 800, 0.01, (3, 3)],
#  ['lbfgs', 'logistic', 800, 0.01, (2, 4)],
#  ['lbfgs', 'logistic', 800, 0.01, (1, 5)],
#  ['lbfgs', 'logistic', 800, 0.01, (9,)],
#  ['lbfgs', 'logistic', 800, 0.01, (8, 1)],
#  ['lbfgs', 'logistic', 800, 0.01, (7, 2)],
#  ['lbfgs', 'logistic', 800, 0.01, (6, 3)],
#  ['lbfgs', 'logistic', 800, 0.01, (5, 4)],
#  ['lbfgs', 'logistic', 800, 0.01, (4, 5)],
#  ['lbfgs', 'logistic', 800, 0.01, (3, 6)],
#  ['lbfgs', 'logistic', 800, 0.01, (2, 7)],
#  ['lbfgs', 'logistic', 800, 0.01, (1, 8)],
#  ['lbfgs', 'logistic', 800, 0.0005, (2,)],
#  ['lbfgs', 'logistic', 800, 0.0005, (1, 1)],
#  ['lbfgs', 'logistic', 800, 0.0005, (6,)],
#  ['lbfgs', 'logistic', 800, 0.0005, (5, 1)],
#  ['lbfgs', 'logistic', 800, 0.0005, (4, 2)],
#  ['lbfgs', 'logistic', 800, 0.0005, (3, 3)],
#  ['lbfgs', 'logistic', 800, 0.0005, (2, 4)],
#  ['lbfgs', 'logistic', 800, 0.0005, (1, 5)],
#  ['lbfgs', 'logistic', 800, 0.0005, (9,)],
#  ['lbfgs', 'logistic', 800, 0.0005, (8, 1)],
#  ['lbfgs', 'logistic', 800, 0.0005, (7, 2)],
#  ['lbfgs', 'logistic', 800, 0.0005, (6, 3)],
#  ['lbfgs', 'logistic', 800, 0.0005, (5, 4)],
#  ['lbfgs', 'logistic', 800, 0.0005, (4, 5)],
#  ['lbfgs', 'logistic', 800, 0.0005, (3, 6)],
#  ['lbfgs', 'logistic', 800, 0.0005, (2, 7)],
#  ['lbfgs', 'logistic', 800, 0.0005, (1, 8)],
#  ['lbfgs', 'logistic', 1000, 0.001, (2,)],
#  ['lbfgs', 'logistic', 1000, 0.001, (1, 1)],
#  ['lbfgs', 'logistic', 1000, 0.001, (6,)],
#  ['lbfgs', 'logistic', 1000, 0.001, (5, 1)],
#  ['lbfgs', 'logistic', 1000, 0.001, (4, 2)],
#  ['lbfgs', 'logistic', 1000, 0.001, (3, 3)],
#  ['lbfgs', 'logistic', 1000, 0.001, (2, 4)],
#  ['lbfgs', 'logistic', 1000, 0.001, (1, 5)],
#  ['lbfgs', 'logistic', 1000, 0.001, (9,)],
#  ['lbfgs', 'logistic', 1000, 0.001, (8, 1)],
#  ['lbfgs', 'logistic', 1000, 0.001, (7, 2)],
#  ['lbfgs', 'logistic', 1000, 0.001, (6, 3)],
#  ['lbfgs', 'logistic', 1000, 0.001, (5, 4)],
#  ['lbfgs', 'logistic', 1000, 0.001, (4, 5)],
#  ['lbfgs', 'logistic', 1000, 0.001, (3, 6)],
#  ['lbfgs', 'logistic', 1000, 0.001, (2, 7)],
#  ['lbfgs', 'logistic', 1000, 0.001, (1, 8)],
#  ['lbfgs', 'logistic', 1000, 0.003, (2,)],
#  ['lbfgs', 'logistic', 1000, 0.003, (1, 1)],
#  ['lbfgs', 'logistic', 1000, 0.003, (6,)],
#  ['lbfgs', 'logistic', 1000, 0.003, (5, 1)],
#  ['lbfgs', 'logistic', 1000, 0.003, (4, 2)],
#  ['lbfgs', 'logistic', 1000, 0.003, (3, 3)],
#  ['lbfgs', 'logistic', 1000, 0.003, (2, 4)],
#  ['lbfgs', 'logistic', 1000, 0.003, (1, 5)],
#  ['lbfgs', 'logistic', 1000, 0.003, (9,)],
#  ['lbfgs', 'logistic', 1000, 0.003, (8, 1)],
#  ['lbfgs', 'logistic', 1000, 0.003, (7, 2)],
#  ['lbfgs', 'logistic', 1000, 0.003, (6, 3)],
#  ['lbfgs', 'logistic', 1000, 0.003, (5, 4)],
#  ['lbfgs', 'logistic', 1000, 0.003, (4, 5)],
#  ['lbfgs', 'logistic', 1000, 0.003, (3, 6)],
#  ['lbfgs', 'logistic', 1000, 0.003, (2, 7)],
#  ['lbfgs', 'logistic', 1000, 0.003, (1, 8)],
#  ['lbfgs', 'logistic', 1000, 0.01, (2,)],
#  ['lbfgs', 'logistic', 1000, 0.01, (1, 1)],
#  ['lbfgs', 'logistic', 1000, 0.01, (6,)],
#  ['lbfgs', 'logistic', 1000, 0.01, (5, 1)],
#  ['lbfgs', 'logistic', 1000, 0.01, (4, 2)],
#  ['lbfgs', 'logistic', 1000, 0.01, (3, 3)],
#  ['lbfgs', 'logistic', 1000, 0.01, (2, 4)],
#  ['lbfgs', 'logistic', 1000, 0.01, (1, 5)],
#  ['lbfgs', 'logistic', 1000, 0.01, (9,)],
#  ['lbfgs', 'logistic', 1000, 0.01, (8, 1)],
#  ['lbfgs', 'logistic', 1000, 0.01, (7, 2)],
#  ['lbfgs', 'logistic', 1000, 0.01, (6, 3)],
#  ['lbfgs', 'logistic', 1000, 0.01, (5, 4)],
#  ['lbfgs', 'logistic', 1000, 0.01, (4, 5)],
#  ['lbfgs', 'logistic', 1000, 0.01, (3, 6)],
#  ['lbfgs', 'logistic', 1000, 0.01, (2, 7)],
#  ['lbfgs', 'logistic', 1000, 0.01, (1, 8)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (2,)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (1, 1)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (6,)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (5, 1)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (4, 2)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (3, 3)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (2, 4)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (1, 5)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (9,)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (8, 1)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (7, 2)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (6, 3)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (5, 4)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (4, 5)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (3, 6)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (2, 7)],
#  ['lbfgs', 'logistic', 1000, 0.0005, (1, 8)],
#  ['lbfgs', 'relu', 600, 0.001, (2,)],
#  ['lbfgs', 'relu', 600, 0.001, (1, 1)],
#  ['lbfgs', 'relu', 600, 0.001, (6,)],
#  ['lbfgs', 'relu', 600, 0.001, (5, 1)],
#  ['lbfgs', 'relu', 600, 0.001, (4, 2)],
#  ['lbfgs', 'relu', 600, 0.001, (3, 3)],
#  ['lbfgs', 'relu', 600, 0.001, (2, 4)],
#  ['lbfgs', 'relu', 600, 0.001, (1, 5)],
#  ['lbfgs', 'relu', 600, 0.001, (9,)],
#  ['lbfgs', 'relu', 600, 0.001, (8, 1)],
#  ['lbfgs', 'relu', 600, 0.001, (7, 2)],
#  ['lbfgs', 'relu', 600, 0.001, (6, 3)],
#  ['lbfgs', 'relu', 600, 0.001, (5, 4)],
#  ['lbfgs', 'relu', 600, 0.001, (4, 5)],
#  ['lbfgs', 'relu', 600, 0.001, (3, 6)],
#  ['lbfgs', 'relu', 600, 0.001, (2, 7)],
#  ['lbfgs', 'relu', 600, 0.001, (1, 8)],
#  ['lbfgs', 'relu', 600, 0.003, (2,)],
#  ['lbfgs', 'relu', 600, 0.003, (1, 1)],
#  ['lbfgs', 'relu', 600, 0.003, (6,)],
#  ['lbfgs', 'relu', 600, 0.003, (5, 1)],
#  ['lbfgs', 'relu', 600, 0.003, (4, 2)],
#  ['lbfgs', 'relu', 600, 0.003, (3, 3)],
#  ['lbfgs', 'relu', 600, 0.003, (2, 4)],
#  ['lbfgs', 'relu', 600, 0.003, (1, 5)],
#  ['lbfgs', 'relu', 600, 0.003, (9,)],
#  ['lbfgs', 'relu', 600, 0.003, (8, 1)],
#  ['lbfgs', 'relu', 600, 0.003, (7, 2)],
#  ['lbfgs', 'relu', 600, 0.003, (6, 3)],
#  ['lbfgs', 'relu', 600, 0.003, (5, 4)],
#  ['lbfgs', 'relu', 600, 0.003, (4, 5)],
#  ['lbfgs', 'relu', 600, 0.003, (3, 6)],
#  ['lbfgs', 'relu', 600, 0.003, (2, 7)],
#  ['lbfgs', 'relu', 600, 0.003, (1, 8)],
#  ['lbfgs', 'relu', 600, 0.01, (2,)],
#  ['lbfgs', 'relu', 600, 0.01, (1, 1)],
#  ['lbfgs', 'relu', 600, 0.01, (6,)],
#  ['lbfgs', 'relu', 600, 0.01, (5, 1)],
#  ['lbfgs', 'relu', 600, 0.01, (4, 2)],
#  ['lbfgs', 'relu', 600, 0.01, (3, 3)],
#  ['lbfgs', 'relu', 600, 0.01, (2, 4)],
#  ['lbfgs', 'relu', 600, 0.01, (1, 5)],
#  ['lbfgs', 'relu', 600, 0.01, (9,)],
#  ['lbfgs', 'relu', 600, 0.01, (8, 1)],
#  ['lbfgs', 'relu', 600, 0.01, (7, 2)],
#  ['lbfgs', 'relu', 600, 0.01, (6, 3)],
#  ['lbfgs', 'relu', 600, 0.01, (5, 4)],
#  ['lbfgs', 'relu', 600, 0.01, (4, 5)],
#  ['lbfgs', 'relu', 600, 0.01, (3, 6)],
#  ['lbfgs', 'relu', 600, 0.01, (2, 7)],
#  ['lbfgs', 'relu', 600, 0.01, (1, 8)],
#  ['lbfgs', 'relu', 600, 0.0005, (2,)],
#  ['lbfgs', 'relu', 600, 0.0005, (1, 1)],
#  ['lbfgs', 'relu', 600, 0.0005, (6,)],
#  ['lbfgs', 'relu', 600, 0.0005, (5, 1)],
#  ['lbfgs', 'relu', 600, 0.0005, (4, 2)],
#  ['lbfgs', 'relu', 600, 0.0005, (3, 3)],
#  ['lbfgs', 'relu', 600, 0.0005, (2, 4)],
#  ['lbfgs', 'relu', 600, 0.0005, (1, 5)],
#  ['lbfgs', 'relu', 600, 0.0005, (9,)],
#  ['lbfgs', 'relu', 600, 0.0005, (8, 1)],
#  ['lbfgs', 'relu', 600, 0.0005, (7, 2)],
#  ['lbfgs', 'relu', 600, 0.0005, (6, 3)],
#  ['lbfgs', 'relu', 600, 0.0005, (5, 4)],
#  ['lbfgs', 'relu', 600, 0.0005, (4, 5)],
#  ['lbfgs', 'relu', 600, 0.0005, (3, 6)],
#  ['lbfgs', 'relu', 600, 0.0005, (2, 7)],
#  ['lbfgs', 'relu', 600, 0.0005, (1, 8)],
#  ['lbfgs', 'relu', 800, 0.001, (2,)],
#  ['lbfgs', 'relu', 800, 0.001, (1, 1)],
#  ['lbfgs', 'relu', 800, 0.001, (6,)],
#  ['lbfgs', 'relu', 800, 0.001, (5, 1)],
#  ['lbfgs', 'relu', 800, 0.001, (4, 2)],
#  ['lbfgs', 'relu', 800, 0.001, (3, 3)],
#  ['lbfgs', 'relu', 800, 0.001, (2, 4)],
#  ['lbfgs', 'relu', 800, 0.001, (1, 5)],
#  ['lbfgs', 'relu', 800, 0.001, (9,)],
#  ['lbfgs', 'relu', 800, 0.001, (8, 1)],
#  ['lbfgs', 'relu', 800, 0.001, (7, 2)],
#  ['lbfgs', 'relu', 800, 0.001, (6, 3)],
#  ['lbfgs', 'relu', 800, 0.001, (5, 4)],
#  ['lbfgs', 'relu', 800, 0.001, (4, 5)],
#  ['lbfgs', 'relu', 800, 0.001, (3, 6)],
#  ['lbfgs', 'relu', 800, 0.001, (2, 7)],
#  ['lbfgs', 'relu', 800, 0.001, (1, 8)],
#  ['lbfgs', 'relu', 800, 0.003, (2,)],
#  ['lbfgs', 'relu', 800, 0.003, (1, 1)],
#  ['lbfgs', 'relu', 800, 0.003, (6,)],
#  ['lbfgs', 'relu', 800, 0.003, (5, 1)],
#  ['lbfgs', 'relu', 800, 0.003, (4, 2)],
#  ['lbfgs', 'relu', 800, 0.003, (3, 3)],
#  ['lbfgs', 'relu', 800, 0.003, (2, 4)],
#  ['lbfgs', 'relu', 800, 0.003, (1, 5)],
#  ['lbfgs', 'relu', 800, 0.003, (9,)],
#  ['lbfgs', 'relu', 800, 0.003, (8, 1)],
#  ['lbfgs', 'relu', 800, 0.003, (7, 2)],
#  ['lbfgs', 'relu', 800, 0.003, (6, 3)],
#  ['lbfgs', 'relu', 800, 0.003, (5, 4)],
#  ['lbfgs', 'relu', 800, 0.003, (4, 5)],
#  ['lbfgs', 'relu', 800, 0.003, (3, 6)],
#  ['lbfgs', 'relu', 800, 0.003, (2, 7)],
#  ['lbfgs', 'relu', 800, 0.003, (1, 8)],
#  ['lbfgs', 'relu', 800, 0.01, (2,)],
#  ['lbfgs', 'relu', 800, 0.01, (1, 1)],
#  ['lbfgs', 'relu', 800, 0.01, (6,)],
#  ['lbfgs', 'relu', 800, 0.01, (5, 1)],
#  ['lbfgs', 'relu', 800, 0.01, (4, 2)],
#  ['lbfgs', 'relu', 800, 0.01, (3, 3)],
#  ['lbfgs', 'relu', 800, 0.01, (2, 4)],
#  ['lbfgs', 'relu', 800, 0.01, (1, 5)],
#  ['lbfgs', 'relu', 800, 0.01, (9,)],
#  ['lbfgs', 'relu', 800, 0.01, (8, 1)],
#  ['lbfgs', 'relu', 800, 0.01, (7, 2)],
#  ['lbfgs', 'relu', 800, 0.01, (6, 3)],
#  ['lbfgs', 'relu', 800, 0.01, (5, 4)],
#  ['lbfgs', 'relu', 800, 0.01, (4, 5)],
#  ['lbfgs', 'relu', 800, 0.01, (3, 6)],
#  ['lbfgs', 'relu', 800, 0.01, (2, 7)],
#  ['lbfgs', 'relu', 800, 0.01, (1, 8)],
#  ['lbfgs', 'relu', 800, 0.0005, (2,)],
#  ['lbfgs', 'relu', 800, 0.0005, (1, 1)],
#  ['lbfgs', 'relu', 800, 0.0005, (6,)],
#  ['lbfgs', 'relu', 800, 0.0005, (5, 1)],
#  ['lbfgs', 'relu', 800, 0.0005, (4, 2)],
#  ['lbfgs', 'relu', 800, 0.0005, (3, 3)],
#  ['lbfgs', 'relu', 800, 0.0005, (2, 4)],
#  ['lbfgs', 'relu', 800, 0.0005, (1, 5)],
#  ['lbfgs', 'relu', 800, 0.0005, (9,)],
#  ['lbfgs', 'relu', 800, 0.0005, (8, 1)],
#  ['lbfgs', 'relu', 800, 0.0005, (7, 2)],
#  ['lbfgs', 'relu', 800, 0.0005, (6, 3)],
#  ['lbfgs', 'relu', 800, 0.0005, (5, 4)],
#  ['lbfgs', 'relu', 800, 0.0005, (4, 5)],
#  ['lbfgs', 'relu', 800, 0.0005, (3, 6)],
#  ['lbfgs', 'relu', 800, 0.0005, (2, 7)],
#  ['lbfgs', 'relu', 800, 0.0005, (1, 8)],
#  ['lbfgs', 'relu', 1000, 0.001, (2,)],
#  ['lbfgs', 'relu', 1000, 0.001, (1, 1)],
#  ['lbfgs', 'relu', 1000, 0.001, (6,)],
#  ['lbfgs', 'relu', 1000, 0.001, (5, 1)],
#  ['lbfgs', 'relu', 1000, 0.001, (4, 2)],
#  ['lbfgs', 'relu', 1000, 0.001, (3, 3)],
#  ['lbfgs', 'relu', 1000, 0.001, (2, 4)],
#  ['lbfgs', 'relu', 1000, 0.001, (1, 5)],
#  ['lbfgs', 'relu', 1000, 0.001, (9,)],
#  ['lbfgs', 'relu', 1000, 0.001, (8, 1)],
#  ['lbfgs', 'relu', 1000, 0.001, (7, 2)],
#  ['lbfgs', 'relu', 1000, 0.001, (6, 3)],
#  ['lbfgs', 'relu', 1000, 0.001, (5, 4)],
#  ['lbfgs', 'relu', 1000, 0.001, (4, 5)],
#  ['lbfgs', 'relu', 1000, 0.001, (3, 6)],
#  ['lbfgs', 'relu', 1000, 0.001, (2, 7)],
#  ['lbfgs', 'relu', 1000, 0.001, (1, 8)],
#  ['lbfgs', 'relu', 1000, 0.003, (2,)],
#  ['lbfgs', 'relu', 1000, 0.003, (1, 1)],
#  ['lbfgs', 'relu', 1000, 0.003, (6,)],
#  ['lbfgs', 'relu', 1000, 0.003, (5, 1)],
#  ['lbfgs', 'relu', 1000, 0.003, (4, 2)],
#  ['lbfgs', 'relu', 1000, 0.003, (3, 3)],
#  ['lbfgs', 'relu', 1000, 0.003, (2, 4)],
#  ['lbfgs', 'relu', 1000, 0.003, (1, 5)],
#  ['lbfgs', 'relu', 1000, 0.003, (9,)],
#  ['lbfgs', 'relu', 1000, 0.003, (8, 1)],
#  ['lbfgs', 'relu', 1000, 0.003, (7, 2)],
#  ['lbfgs', 'relu', 1000, 0.003, (6, 3)],
#  ['lbfgs', 'relu', 1000, 0.003, (5, 4)],
#  ['lbfgs', 'relu', 1000, 0.003, (4, 5)],
#  ['lbfgs', 'relu', 1000, 0.003, (3, 6)],
#  ['lbfgs', 'relu', 1000, 0.003, (2, 7)],
#  ['lbfgs', 'relu', 1000, 0.003, (1, 8)],
#  ['lbfgs', 'relu', 1000, 0.01, (2,)],
#  ['lbfgs', 'relu', 1000, 0.01, (1, 1)],
#  ['lbfgs', 'relu', 1000, 0.01, (6,)],
#  ['lbfgs', 'relu', 1000, 0.01, (5, 1)],
#  ['lbfgs', 'relu', 1000, 0.01, (4, 2)],
#  ['lbfgs', 'relu', 1000, 0.01, (3, 3)],
#  ['lbfgs', 'relu', 1000, 0.01, (2, 4)],
#  ['lbfgs', 'relu', 1000, 0.01, (1, 5)],
#  ['lbfgs', 'relu', 1000, 0.01, (9,)],
#  ['lbfgs', 'relu', 1000, 0.01, (8, 1)],
#  ['lbfgs', 'relu', 1000, 0.01, (7, 2)],
#  ['lbfgs', 'relu', 1000, 0.01, (6, 3)],
#  ['lbfgs', 'relu', 1000, 0.01, (5, 4)],
#  ['lbfgs', 'relu', 1000, 0.01, (4, 5)],
#  ['lbfgs', 'relu', 1000, 0.01, (3, 6)],
#  ['lbfgs', 'relu', 1000, 0.01, (2, 7)],
#  ['lbfgs', 'relu', 1000, 0.01, (1, 8)],
#  ['lbfgs', 'relu', 1000, 0.0005, (2,)],
#  ['lbfgs', 'relu', 1000, 0.0005, (1, 1)],
#  ['lbfgs', 'relu', 1000, 0.0005, (6,)],
#  ['lbfgs', 'relu', 1000, 0.0005, (5, 1)],
#  ['lbfgs', 'relu', 1000, 0.0005, (4, 2)],
#  ['lbfgs', 'relu', 1000, 0.0005, (3, 3)],
#  ['lbfgs', 'relu', 1000, 0.0005, (2, 4)],
#  ['lbfgs', 'relu', 1000, 0.0005, (1, 5)],
#  ['lbfgs', 'relu', 1000, 0.0005, (9,)],
#  ['lbfgs', 'relu', 1000, 0.0005, (8, 1)],
#  ['lbfgs', 'relu', 1000, 0.0005, (7, 2)],
#  ['lbfgs', 'relu', 1000, 0.0005, (6, 3)],
#  ['lbfgs', 'relu', 1000, 0.0005, (5, 4)],
#  ['lbfgs', 'relu', 1000, 0.0005, (4, 5)],
#  ['lbfgs', 'relu', 1000, 0.0005, (3, 6)],
#  ['lbfgs', 'relu', 1000, 0.0005, (2, 7)],
#  ['lbfgs', 'relu', 1000, 0.0005, (1, 8)],
#  ['lbfgs', 'tanh', 600, 0.001, (2,)],
#  ['lbfgs', 'tanh', 600, 0.001, (1, 1)],
#  ['lbfgs', 'tanh', 600, 0.001, (6,)],
#  ['lbfgs', 'tanh', 600, 0.001, (5, 1)],
#  ['lbfgs', 'tanh', 600, 0.001, (4, 2)],
#  ['lbfgs', 'tanh', 600, 0.001, (3, 3)],
#  ['lbfgs', 'tanh', 600, 0.001, (2, 4)],
#  ['lbfgs', 'tanh', 600, 0.001, (1, 5)],
#  ['lbfgs', 'tanh', 600, 0.001, (9,)],
#  ['lbfgs', 'tanh', 600, 0.001, (8, 1)],
#  ['lbfgs', 'tanh', 600, 0.001, (7, 2)],
#  ['lbfgs', 'tanh', 600, 0.001, (6, 3)],
#  ['lbfgs', 'tanh', 600, 0.001, (5, 4)],
#  ['lbfgs', 'tanh', 600, 0.001, (4, 5)],
#  ['lbfgs', 'tanh', 600, 0.001, (3, 6)],
#  ['lbfgs', 'tanh', 600, 0.001, (2, 7)],
#  ['lbfgs', 'tanh', 600, 0.001, (1, 8)],
#  ['lbfgs', 'tanh', 600, 0.003, (2,)],
#  ['lbfgs', 'tanh', 600, 0.003, (1, 1)],
#  ['lbfgs', 'tanh', 600, 0.003, (6,)],
#  ['lbfgs', 'tanh', 600, 0.003, (5, 1)],
#  ['lbfgs', 'tanh', 600, 0.003, (4, 2)],
#  ['lbfgs', 'tanh', 600, 0.003, (3, 3)],
#  ['lbfgs', 'tanh', 600, 0.003, (2, 4)],
#  ['lbfgs', 'tanh', 600, 0.003, (1, 5)],
#  ['lbfgs', 'tanh', 600, 0.003, (9,)],
#  ['lbfgs', 'tanh', 600, 0.003, (8, 1)],
#  ['lbfgs', 'tanh', 600, 0.003, (7, 2)],
#  ['lbfgs', 'tanh', 600, 0.003, (6, 3)],
#  ['lbfgs', 'tanh', 600, 0.003, (5, 4)],
#  ['lbfgs', 'tanh', 600, 0.003, (4, 5)],
#  ['lbfgs', 'tanh', 600, 0.003, (3, 6)],
#  ['lbfgs', 'tanh', 600, 0.003, (2, 7)],
#  ['lbfgs', 'tanh', 600, 0.003, (1, 8)],
#  ['lbfgs', 'tanh', 600, 0.01, (2,)],
#  ['lbfgs', 'tanh', 600, 0.01, (1, 1)],
#  ['lbfgs', 'tanh', 600, 0.01, (6,)],
#  ['lbfgs', 'tanh', 600, 0.01, (5, 1)],
#  ['lbfgs', 'tanh', 600, 0.01, (4, 2)],
#  ['lbfgs', 'tanh', 600, 0.01, (3, 3)],
#  ['lbfgs', 'tanh', 600, 0.01, (2, 4)],
#  ['lbfgs', 'tanh', 600, 0.01, (1, 5)],
#  ['lbfgs', 'tanh', 600, 0.01, (9,)],
#  ['lbfgs', 'tanh', 600, 0.01, (8, 1)],
#  ['lbfgs', 'tanh', 600, 0.01, (7, 2)],
#  ['lbfgs', 'tanh', 600, 0.01, (6, 3)],
#  ['lbfgs', 'tanh', 600, 0.01, (5, 4)],
#  ['lbfgs', 'tanh', 600, 0.01, (4, 5)],
#  ['lbfgs', 'tanh', 600, 0.01, (3, 6)],
#  ['lbfgs', 'tanh', 600, 0.01, (2, 7)],
#  ['lbfgs', 'tanh', 600, 0.01, (1, 8)],
#  ['lbfgs', 'tanh', 600, 0.0005, (2,)],
#  ['lbfgs', 'tanh', 600, 0.0005, (1, 1)],
#  ['lbfgs', 'tanh', 600, 0.0005, (6,)],
#  ['lbfgs', 'tanh', 600, 0.0005, (5, 1)],
#  ['lbfgs', 'tanh', 600, 0.0005, (4, 2)],
#  ['lbfgs', 'tanh', 600, 0.0005, (3, 3)],
#  ['lbfgs', 'tanh', 600, 0.0005, (2, 4)],
#  ['lbfgs', 'tanh', 600, 0.0005, (1, 5)],
#  ['lbfgs', 'tanh', 600, 0.0005, (9,)],
#  ['lbfgs', 'tanh', 600, 0.0005, (8, 1)],
#  ['lbfgs', 'tanh', 600, 0.0005, (7, 2)],
#  ['lbfgs', 'tanh', 600, 0.0005, (6, 3)],
#  ['lbfgs', 'tanh', 600, 0.0005, (5, 4)],
#  ['lbfgs', 'tanh', 600, 0.0005, (4, 5)],
#  ['lbfgs', 'tanh', 600, 0.0005, (3, 6)],
#  ['lbfgs', 'tanh', 600, 0.0005, (2, 7)],
#  ['lbfgs', 'tanh', 600, 0.0005, (1, 8)],
#  ['lbfgs', 'tanh', 800, 0.001, (2,)],
#  ['lbfgs', 'tanh', 800, 0.001, (1, 1)],
#  ['lbfgs', 'tanh', 800, 0.001, (6,)],
#  ['lbfgs', 'tanh', 800, 0.001, (5, 1)],
#  ['lbfgs', 'tanh', 800, 0.001, (4, 2)],
#  ['lbfgs', 'tanh', 800, 0.001, (3, 3)],
#  ['lbfgs', 'tanh', 800, 0.001, (2, 4)],
#  ['lbfgs', 'tanh', 800, 0.001, (1, 5)],
#  ['lbfgs', 'tanh', 800, 0.001, (9,)],
#  ['lbfgs', 'tanh', 800, 0.001, (8, 1)],
#  ['lbfgs', 'tanh', 800, 0.001, (7, 2)],
#  ['lbfgs', 'tanh', 800, 0.001, (6, 3)],
#  ['lbfgs', 'tanh', 800, 0.001, (5, 4)],
#  ['lbfgs', 'tanh', 800, 0.001, (4, 5)],
#  ['lbfgs', 'tanh', 800, 0.001, (3, 6)],
#  ['lbfgs', 'tanh', 800, 0.001, (2, 7)],
#  ['lbfgs', 'tanh', 800, 0.001, (1, 8)],
#  ['lbfgs', 'tanh', 800, 0.003, (2,)],
#  ['lbfgs', 'tanh', 800, 0.003, (1, 1)],
#  ['lbfgs', 'tanh', 800, 0.003, (6,)],
#  ['lbfgs', 'tanh', 800, 0.003, (5, 1)],
#  ['lbfgs', 'tanh', 800, 0.003, (4, 2)],
#  ['lbfgs', 'tanh', 800, 0.003, (3, 3)],
#  ['lbfgs', 'tanh', 800, 0.003, (2, 4)],
#  ['lbfgs', 'tanh', 800, 0.003, (1, 5)],
#  ['lbfgs', 'tanh', 800, 0.003, (9,)],
#  ['lbfgs', 'tanh', 800, 0.003, (8, 1)],
#  ['lbfgs', 'tanh', 800, 0.003, (7, 2)],
#  ['lbfgs', 'tanh', 800, 0.003, (6, 3)],
#  ['lbfgs', 'tanh', 800, 0.003, (5, 4)],
#  ['lbfgs', 'tanh', 800, 0.003, (4, 5)],
#  ['lbfgs', 'tanh', 800, 0.003, (3, 6)],
#  ['lbfgs', 'tanh', 800, 0.003, (2, 7)],
#  ['lbfgs', 'tanh', 800, 0.003, (1, 8)],
#  ['lbfgs', 'tanh', 800, 0.01, (2,)],
#  ['lbfgs', 'tanh', 800, 0.01, (1, 1)],
#  ['lbfgs', 'tanh', 800, 0.01, (6,)],
#  ['lbfgs', 'tanh', 800, 0.01, (5, 1)],
#  ['lbfgs', 'tanh', 800, 0.01, (4, 2)],
#  ['lbfgs', 'tanh', 800, 0.01, (3, 3)],
#  ['lbfgs', 'tanh', 800, 0.01, (2, 4)],
#  ['lbfgs', 'tanh', 800, 0.01, (1, 5)],
#  ['lbfgs', 'tanh', 800, 0.01, (9,)],
#  ['lbfgs', 'tanh', 800, 0.01, (8, 1)],
#  ['lbfgs', 'tanh', 800, 0.01, (7, 2)],
#  ['lbfgs', 'tanh', 800, 0.01, (6, 3)],
#  ['lbfgs', 'tanh', 800, 0.01, (5, 4)],
#  ['lbfgs', 'tanh', 800, 0.01, (4, 5)],
#  ['lbfgs', 'tanh', 800, 0.01, (3, 6)],
#  ['lbfgs', 'tanh', 800, 0.01, (2, 7)],
#  ['lbfgs', 'tanh', 800, 0.01, (1, 8)],
#  ['lbfgs', 'tanh', 800, 0.0005, (2,)],
#  ['lbfgs', 'tanh', 800, 0.0005, (1, 1)],
#  ['lbfgs', 'tanh', 800, 0.0005, (6,)],
#  ['lbfgs', 'tanh', 800, 0.0005, (5, 1)],
#  ['lbfgs', 'tanh', 800, 0.0005, (4, 2)],
#  ['lbfgs', 'tanh', 800, 0.0005, (3, 3)],
#  ['lbfgs', 'tanh', 800, 0.0005, (2, 4)],
#  ['lbfgs', 'tanh', 800, 0.0005, (1, 5)],
#  ['lbfgs', 'tanh', 800, 0.0005, (9,)],
#  ['lbfgs', 'tanh', 800, 0.0005, (8, 1)],
#  ['lbfgs', 'tanh', 800, 0.0005, (7, 2)],
#  ['lbfgs', 'tanh', 800, 0.0005, (6, 3)],
#  ['lbfgs', 'tanh', 800, 0.0005, (5, 4)],
#  ['lbfgs', 'tanh', 800, 0.0005, (4, 5)],
#  ['lbfgs', 'tanh', 800, 0.0005, (3, 6)],
#  ['lbfgs', 'tanh', 800, 0.0005, (2, 7)],
#  ['lbfgs', 'tanh', 800, 0.0005, (1, 8)],
#  ['lbfgs', 'tanh', 1000, 0.001, (2,)],
#  ['lbfgs', 'tanh', 1000, 0.001, (1, 1)],
#  ['lbfgs', 'tanh', 1000, 0.001, (6,)],
#  ['lbfgs', 'tanh', 1000, 0.001, (5, 1)],
#  ['lbfgs', 'tanh', 1000, 0.001, (4, 2)],
#  ['lbfgs', 'tanh', 1000, 0.001, (3, 3)],
#  ['lbfgs', 'tanh', 1000, 0.001, (2, 4)],
#  ['lbfgs', 'tanh', 1000, 0.001, (1, 5)],
#  ['lbfgs', 'tanh', 1000, 0.001, (9,)],
#  ['lbfgs', 'tanh', 1000, 0.001, (8, 1)],
#  ['lbfgs', 'tanh', 1000, 0.001, (7, 2)],
#  ['lbfgs', 'tanh', 1000, 0.001, (6, 3)],
#  ['lbfgs', 'tanh', 1000, 0.001, (5, 4)],
#  ['lbfgs', 'tanh', 1000, 0.001, (4, 5)],
#  ['lbfgs', 'tanh', 1000, 0.001, (3, 6)],
#  ['lbfgs', 'tanh', 1000, 0.001, (2, 7)],
#  ['lbfgs', 'tanh', 1000, 0.001, (1, 8)],
#  ['lbfgs', 'tanh', 1000, 0.003, (2,)],
#  ['lbfgs', 'tanh', 1000, 0.003, (1, 1)],
#  ['lbfgs', 'tanh', 1000, 0.003, (6,)],
#  ['lbfgs', 'tanh', 1000, 0.003, (5, 1)],
#  ['lbfgs', 'tanh', 1000, 0.003, (4, 2)],
#  ['lbfgs', 'tanh', 1000, 0.003, (3, 3)],
#  ['lbfgs', 'tanh', 1000, 0.003, (2, 4)],
#  ['lbfgs', 'tanh', 1000, 0.003, (1, 5)],
#  ['lbfgs', 'tanh', 1000, 0.003, (9,)],
#  ['lbfgs', 'tanh', 1000, 0.003, (8, 1)],
#  ['lbfgs', 'tanh', 1000, 0.003, (7, 2)],
#  ['lbfgs', 'tanh', 1000, 0.003, (6, 3)],
#  ['lbfgs', 'tanh', 1000, 0.003, (5, 4)],
#  ['lbfgs', 'tanh', 1000, 0.003, (4, 5)],
#  ['lbfgs', 'tanh', 1000, 0.003, (3, 6)],
#  ['lbfgs', 'tanh', 1000, 0.003, (2, 7)],
#  ['lbfgs', 'tanh', 1000, 0.003, (1, 8)],
#  ['lbfgs', 'tanh', 1000, 0.01, (2,)],
#  ['lbfgs', 'tanh', 1000, 0.01, (1, 1)],
#  ['lbfgs', 'tanh', 1000, 0.01, (6,)],
#  ['lbfgs', 'tanh', 1000, 0.01, (5, 1)],
#  ['lbfgs', 'tanh', 1000, 0.01, (4, 2)],
#  ['lbfgs', 'tanh', 1000, 0.01, (3, 3)],
#  ['lbfgs', 'tanh', 1000, 0.01, (2, 4)],
#  ['lbfgs', 'tanh', 1000, 0.01, (1, 5)],
#  ['lbfgs', 'tanh', 1000, 0.01, (9,)],
#  ['lbfgs', 'tanh', 1000, 0.01, (8, 1)],
#  ['lbfgs', 'tanh', 1000, 0.01, (7, 2)],
#  ['lbfgs', 'tanh', 1000, 0.01, (6, 3)],
#  ['lbfgs', 'tanh', 1000, 0.01, (5, 4)],
#  ['lbfgs', 'tanh', 1000, 0.01, (4, 5)],
#  ['lbfgs', 'tanh', 1000, 0.01, (3, 6)],
#  ['lbfgs', 'tanh', 1000, 0.01, (2, 7)],
#  ['lbfgs', 'tanh', 1000, 0.01, (1, 8)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (2,)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (1, 1)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (6,)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (5, 1)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (4, 2)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (3, 3)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (2, 4)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (1, 5)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (9,)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (8, 1)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (7, 2)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (6, 3)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (5, 4)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (4, 5)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (3, 6)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (2, 7)],
#  ['lbfgs', 'tanh', 1000, 0.0005, (1, 8)]]

# %%
results = defaultdict()
results['models'] = []
results['y_preds'] = []
results['cms'] = []
results['accuracies'] = []
results['f1_scores'] = []

# %%
for i, (s, a, m, l, h) in zip(range(len(models)),models):
    clf = MLPClassifier(solver = s, activation=a, hidden_layer_sizes=h, learning_rate_init=l, max_iter=m)
    clf.fit(X_train, y_train)
    
    results['models'].append([s, a, h, l, m])
    
    y_pred = clf.predict(X_test)
    results['y_preds'].append(y_pred)
    
    cm = confusion_matrix(y_pred=y_pred, y_true= y_test)
    results['cms'].append(cm.flatten())
    
    print("Modelo {}".format(i))
    print('Acurácia: {}%'.format(round(cm.diagonal().sum() / cm.sum() * 100, 2)))
    print('F-Score: {}%\n'.format(round(f1_score(y_pred=y_pred, y_true=y_test) * 100, 2)))
    
    results['accuracies'].append(round(cm.diagonal().sum() / cm.sum() * 100, 2))
    results['f1_scores'].append(round(f1_score(y_pred=y_pred, y_true=y_test) * 100, 2))
# Out:
# Modelo 0
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 1
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 2
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 3
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 4
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 5
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 6
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 7
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 8
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 9
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 10
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 11
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 12
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 13
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 14
# Acurácia: 62.5%
# F-Score: 60.87%
#
# Modelo 15
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 16
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 17
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 18
# Acurácia: 83.33%
# F-Score: 75.0%
# C:\Users\Inventario-LSE\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Modelo 19
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 20
# Acurácia: 91.67%
# F-Score: 87.5%
#
# Modelo 21
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 22
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 23
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 24
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 25
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 26
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 27
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 28
# Acurácia: 70.83%
# F-Score: 36.36%
#
# Modelo 29
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 30
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 31
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 32
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 33
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 34
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 35
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 36
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 37
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 38
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 39
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 40
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 41
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 42
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 43
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 44
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 45
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 46
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 47
# Acurácia: 70.83%
# F-Score: 58.82%
#
# Modelo 48
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 49
# Acurácia: 58.33%
# F-Score: 50.0%
#
# Modelo 50
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 51
# Acurácia: 95.83%
# F-Score: 94.12%
#
# Modelo 52
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 53
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 54
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 55
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 56
# Acurácia: 70.83%
# F-Score: 58.82%
#
# Modelo 57
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 58
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 59
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 60
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 61
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 62
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 63
# Acurácia: 66.67%
# F-Score: 63.64%
#
# Modelo 64
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 65
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 66
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 67
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 68
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 69
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 70
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 71
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 72
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 73
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 74
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 75
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 76
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 77
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 78
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 79
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 80
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 81
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 82
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 83
# Acurácia: 91.67%
# F-Score: 87.5%
#
# Modelo 84
# Acurácia: 62.5%
# F-Score: 40.0%
#
# Modelo 85
# Acurácia: 95.83%
# F-Score: 94.12%
#
# Modelo 86
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 87
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 88
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 89
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 90
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 91
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 92
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 93
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 94
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 95
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 96
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 97
# Acurácia: 58.33%
# F-Score: 58.33%
#
# Modelo 98
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 99
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 100
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 101
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 102
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 103
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 104
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 105
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 106
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 107
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 108
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 109
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 110
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 111
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 112
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 113
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 114
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 115
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 116
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 117
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 118
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 119
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 120
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 121
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 122
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 123
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 124
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 125
# Acurácia: 66.67%
# F-Score: 63.64%
#
# Modelo 126
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 127
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 128
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 129
# Acurácia: 62.5%
# F-Score: 64.0%
#
# Modelo 130
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 131
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 132
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 133
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 134
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 135
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 136
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 137
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 138
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 139
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 140
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 141
# Acurácia: 75.0%
# F-Score: 62.5%
#
# Modelo 142
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 143
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 144
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 145
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 146
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 147
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 148
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 149
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 150
# Acurácia: 58.33%
# F-Score: 44.44%
#
# Modelo 151
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 152
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 153
# Acurácia: 75.0%
# F-Score: 57.14%
#
# Modelo 154
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 155
# Acurácia: 66.67%
# F-Score: 50.0%
#
# Modelo 156
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 157
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 158
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 159
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 160
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 161
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 162
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 163
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 164
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 165
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 166
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 167
# Acurácia: 50.0%
# F-Score: 53.85%
#
# Modelo 168
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 169
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 170
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 171
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 172
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 173
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 174
# Acurácia: 66.67%
# F-Score: 50.0%
#
# Modelo 175
# Acurácia: 62.5%
# F-Score: 57.14%
#
# Modelo 176
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 177
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 178
# Acurácia: 62.5%
# F-Score: 60.87%
#
# Modelo 179
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 180
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 181
# Acurácia: 62.5%
# F-Score: 57.14%
#
# Modelo 182
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 183
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 184
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 185
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 186
# Acurácia: 70.83%
# F-Score: 58.82%
#
# Modelo 187
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 188
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 189
# Acurácia: 79.17%
# F-Score: 66.67%
#
# Modelo 190
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 191
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 192
# Acurácia: 95.83%
# F-Score: 94.74%
#
# Modelo 193
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 194
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 195
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 196
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 197
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 198
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 199
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 200
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 201
# Acurácia: 66.67%
# F-Score: 55.56%
#
# Modelo 202
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 203
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 204
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 205
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 206
# Acurácia: 58.33%
# F-Score: 54.55%
#
# Modelo 207
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 208
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 209
# Acurácia: 87.5%
# F-Score: 82.35%
# Modelo 210
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 211
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 212
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 213
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 214
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 215
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 216
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 217
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 218
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 219
# Acurácia: 70.83%
# F-Score: 36.36%
#
# Modelo 220
# Acurácia: 95.83%
# F-Score: 94.74%
#
# Modelo 221
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 222
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 223
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 224
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 225
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 226
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 227
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 228
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 229
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 230
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 231
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 232
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 233
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 234
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 235
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 236
# Acurácia: 70.83%
# F-Score: 36.36%
#
# Modelo 237
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 238
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 239
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 240
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 241
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 242
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 243
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 244
# Acurácia: 45.83%
# F-Score: 58.06%
#
# Modelo 245
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 246
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 247
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 248
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 249
# Acurácia: 66.67%
# F-Score: 63.64%
#
# Modelo 250
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 251
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 252
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 253
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 254
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 255
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 256
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 257
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 258
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 259
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 260
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 261
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 262
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 263
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 264
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 265
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 266
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 267
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 268
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 269
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 270
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 271
# Acurácia: 41.67%
# F-Score: 41.67%
#
# Modelo 272
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 273
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 274
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 275
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 276
# Acurácia: 62.5%
# F-Score: 18.18%
#
# Modelo 277
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 278
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 279
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 280
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 281
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 282
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 283
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 284
# Acurácia: 62.5%
# F-Score: 60.87%
#
# Modelo 285
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 286
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 287
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 288
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 289
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 290
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 291
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 292
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 293
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 294
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 295
# Acurácia: 62.5%
# F-Score: 18.18%
#
# Modelo 296
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 297
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 298
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 299
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 300
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 301
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 302
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 303
# Acurácia: 91.67%
# F-Score: 87.5%
#
# Modelo 304
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 305
# Acurácia: 58.33%
# F-Score: 16.67%
#
# Modelo 306
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 307
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 308
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 309
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 310
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 311
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 312
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 313
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 314
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 315
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 316
# Acurácia: 70.83%
# F-Score: 36.36%
#
# Modelo 317
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 318
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 319
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 320
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 321
# Acurácia: 87.5%
# F-Score: 85.71%
#
# Modelo 322
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 323
# Acurácia: 95.83%
# F-Score: 94.74%
#
# Modelo 324
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 325
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 326
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 327
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 328
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 329
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 330
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 331
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 332
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 333
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 334
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 335
# Acurácia: 75.0%
# F-Score: 62.5%
#
# Modelo 336
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 337
# Acurácia: 66.67%
# F-Score: 63.64%
#
# Modelo 338
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 339
# Acurácia: 79.17%
# F-Score: 66.67%
#
# Modelo 340
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 341
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 342
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 343
# Acurácia: 54.17%
# F-Score: 15.38%
#
# Modelo 344
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 345
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 346
# Acurácia: 66.67%
# F-Score: 66.67%
#
# Modelo 347
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 348
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 349
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 350
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 351
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 352
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 353
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 354
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 355
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 356
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 357
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 358
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 359
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 360
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 361
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 362
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 363
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 364
# Acurácia: 79.17%
# F-Score: 66.67%
#
# Modelo 365
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 366
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 367
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 368
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 369
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 370
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 371
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 372
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 373
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 374
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 375
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 376
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 377
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 378
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 379
# Acurácia: 58.33%
# F-Score: 61.54%
#
# Modelo 380
# Acurácia: 87.5%
# F-Score: 80.0%
#
# Modelo 381
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 382
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 383
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 384
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 385
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 386
# Acurácia: 75.0%
# F-Score: 57.14%
#
# Modelo 387
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 388
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 389
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 390
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 391
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 392
# Acurácia: 66.67%
# F-Score: 33.33%
#
# Modelo 393
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 394
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 395
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 396
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 397
# Acurácia: 79.17%
# F-Score: 78.26%
# Modelo 398
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 399
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 400
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 401
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 402
# Acurácia: 87.5%
# F-Score: 80.0%
#
# Modelo 403
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 404
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 405
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 406
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 407
# Acurácia: 70.83%
# F-Score: 46.15%
#
# Modelo 408
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 409
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 410
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 411
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 412
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 413
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 414
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 415
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 416
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 417
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 418
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 419
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 420
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 421
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 422
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 423
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 424
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 425
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 426
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 427
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 428
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 429
# Acurácia: 66.67%
# F-Score: 33.33%
#
# Modelo 430
# Acurácia: 62.5%
# F-Score: 57.14%
#
# Modelo 431
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 432
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 433
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 434
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 435
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 436
# Acurácia: 66.67%
# F-Score: 63.64%
#
# Modelo 437
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 438
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 439
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 440
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 441
# Acurácia: 58.33%
# F-Score: 0.0%
#
# Modelo 442
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 443
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 444
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 445
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 446
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 447
# Acurácia: 91.67%
# F-Score: 87.5%
#
# Modelo 448
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 449
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 450
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 451
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 452
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 453
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 454
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 455
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 456
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 457
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 458
# Acurácia: 91.67%
# F-Score: 90.0%
#
# Modelo 459
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 460
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 461
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 462
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 463
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 464
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 465
# Acurácia: 75.0%
# F-Score: 57.14%
#
# Modelo 466
# Acurácia: 66.67%
# F-Score: 55.56%
#
# Modelo 467
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 468
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 469
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 470
# Acurácia: 75.0%
# F-Score: 62.5%
#
# Modelo 471
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 472
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 473
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 474
# Acurácia: 70.83%
# F-Score: 53.33%
#
# Modelo 475
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 476
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 477
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 478
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 479
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 480
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 481
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 482
# Acurácia: 62.5%
# F-Score: 66.67%
#
# Modelo 483
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 484
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 485
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 486
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 487
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 488
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 489
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 490
# Acurácia: 66.67%
# F-Score: 50.0%
#
# Modelo 491
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 492
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 493
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 494
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 495
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 496
# Acurácia: 66.67%
# F-Score: 60.0%
#
# Modelo 497
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 498
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 499
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 500
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 501
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 502
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 503
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 504
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 505
# Acurácia: 66.67%
# F-Score: 55.56%
#
# Modelo 506
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 507
# Acurácia: 70.83%
# F-Score: 58.82%
#
# Modelo 508
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 509
# Acurácia: 66.67%
# F-Score: 42.86%
#
# Modelo 510
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 511
# Acurácia: 62.5%
# F-Score: 0.0%
#
# Modelo 512
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 513
# Acurácia: 58.33%
# F-Score: 64.29%
#
# Modelo 514
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 515
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 516
# Acurácia: 91.67%
# F-Score: 87.5%
#
# Modelo 517
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 518
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 519
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 520
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 521
# Acurácia: 75.0%
# F-Score: 62.5%
#
# Modelo 522
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 523
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 524
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 525
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 526
# Acurácia: 62.5%
# F-Score: 66.67%
#
# Modelo 527
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 528
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 529
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 530
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 531
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 532
# Acurácia: 70.83%
# F-Score: 46.15%
#
# Modelo 533
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 534
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 535
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 536
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 537
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 538
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 539
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 540
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 541
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 542
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 543
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 544
# Acurácia: 58.33%
# F-Score: 64.29%
#
# Modelo 545
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 546
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 547
# Acurácia: 95.83%
# F-Score: 94.12%
#
# Modelo 548
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 549
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 550
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 551
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 552
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 553
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 554
# Acurácia: 79.17%
# F-Score: 73.68%
#
# Modelo 555
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 556
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 557
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 558
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 559
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 560
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 561
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 562
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 563
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 564
# Acurácia: 83.33%
# F-Score: 75.0%
#
# Modelo 565
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 566
# Acurácia: 79.17%
# F-Score: 78.26%
#
# Modelo 567
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 568
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 569
# Acurácia: 75.0%
# F-Score: 72.73%
#
# Modelo 570
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 571
# Acurácia: 70.83%
# F-Score: 63.16%
#
# Modelo 572
# Acurácia: 62.5%
# F-Score: 57.14%
#
# Modelo 573
# Acurácia: 70.83%
# F-Score: 69.57%
#
# Modelo 574
# Acurácia: 87.5%
# F-Score: 84.21%
#
# Modelo 575
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 576
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 577
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 578
# Acurácia: 75.0%
# F-Score: 62.5%
#
# Modelo 579
# Acurácia: 83.33%
# F-Score: 81.82%
#
# Modelo 580
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 581
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 582
# Acurácia: 70.83%
# F-Score: 66.67%
# Modelo 583
# Acurácia: 58.33%
# F-Score: 44.44%
#
# Modelo 584
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 585
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 586
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 587
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 588
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 589
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 590
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 591
# Acurácia: 79.17%
# F-Score: 70.59%
#
# Modelo 592
# Acurácia: 83.33%
# F-Score: 80.0%
#
# Modelo 593
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 594
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 595
# Acurácia: 70.83%
# F-Score: 72.0%
#
# Modelo 596
# Acurácia: 75.0%
# F-Score: 75.0%
#
# Modelo 597
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 598
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 599
# Acurácia: 79.17%
# F-Score: 76.19%
#
# Modelo 600
# Acurácia: 91.67%
# F-Score: 88.89%
#
# Modelo 601
# Acurácia: 66.67%
# F-Score: 69.23%
#
# Modelo 602
# Acurácia: 79.17%
# F-Score: 66.67%
#
# Modelo 603
# Acurácia: 66.67%
# F-Score: 50.0%
#
# Modelo 604
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 605
# Acurácia: 87.5%
# F-Score: 82.35%
#
# Modelo 606
# Acurácia: 75.0%
# F-Score: 70.0%
#
# Modelo 607
# Acurácia: 83.33%
# F-Score: 77.78%
#
# Modelo 608
# Acurácia: 70.83%
# F-Score: 66.67%
#
# Modelo 609
# Acurácia: 66.67%
# F-Score: 50.0%
#
# Modelo 610
# Acurácia: 75.0%
# F-Score: 66.67%
#
# Modelo 611
# Acurácia: 79.17%
# F-Score: 66.67%

# %%
best_results_index = [i for i in range(len(results['accuracies'])) if results['accuracies'][i] > 90 and 
                                                                      results['f1_scores'][i] > 90]

# %%
best_models = defaultdict()
best_models['models'] = []
best_models['y_preds'] = []
best_models['cms'] = []
best_models['accuracies'] = []
best_models['f1_scores'] = []

# %%
for i in best_results_index:
    best_models['models'].append(results['models'][i])
    best_models['y_preds'].append(results['y_preds'][i])
    best_models['cms'].append(results['cms'][i])
    best_models['accuracies'].append(results['accuracies'][i])
    best_models['f1_scores'].append(results['f1_scores'][i])

# %%
best_models
# Out:
# defaultdict(None,
#             {'models': [['lbfgs', 'logistic', (2,), 0.0005, 600],
#               ['lbfgs', 'logistic', (2,), 0.003, 800],
#               ['lbfgs', 'logistic', (3, 3), 0.0005, 1000],
#               ['lbfgs', 'relu', (1, 8), 0.001, 600],
#               ['lbfgs', 'relu', (2,), 0.0005, 800],
#               ['lbfgs', 'tanh', (5, 1), 0.001, 1000]],
#              'y_preds': [array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1,
#                      1, 2], dtype=int64),
#               array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1,
#                      1, 2], dtype=int64),
#               array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                      1, 1], dtype=int64),
#               array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                      1, 1], dtype=int64),
#               array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 1, 1,
#                      1, 1], dtype=int64),
#               array([2, 1, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1,
#                      1, 2], dtype=int64)],
#              'cms': [array([ 8,  1,  0, 15]),
#               array([ 8,  1,  0, 15]),
#               array([ 9,  0,  1, 14]),
#               array([ 9,  0,  1, 14]),
#               array([ 9,  0,  1, 14]),
#               array([ 8,  1,  0, 15])],
#              'accuracies': [95.83, 95.83, 95.83, 95.83, 95.83, 95.83],
#              'f1_scores': [94.12, 94.12, 94.74, 94.74, 94.74, 94.12]})

# %%
arq = open('best_models.txt', 'wb')
pickle.dump(best_models, arq)
arq.close()
